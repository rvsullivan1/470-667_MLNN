# %%
print ("Hello World")
# Out:
# Hello World

# %%
s = 3
t = 6
s * t
# Out:
# 18

# %%
import numpy
import pandas
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot([3,2,4],[1,2,3])

# %%
plt.scatter([3,2,4], [1,2,3])

# %% [markdown]
# # Heading
# This is a text cell

# %%
i = 0
while i<=50: 
    print(i)
    i = i + 5
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
1+2+3+4+5
# Out:
# 15

# %%
plt.bar([3,2,4],[1,2,3])
# Out:
# <BarContainer object of 3 artists>
